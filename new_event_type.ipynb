# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 47
#       1 {
#       2   "nbformat": 4,
#       3   "nbformat_minor": 0,
#       4   "metadata": {
#       5     "kernelspec": {
#       6       "display_name": "Python 3",
#       7       "language": "python",
#       8       "name": "python3"
#       9     },
#      10     "language_info": {
#      11       "name": "python"
#      12     }
#      13   },
#      14   "cells": [
#      15     {
#      16       "cell_type": "markdown",
#      17       "metadata": {},
#      18       "source": [
#      19         "# Danish News AI Analysis – Final Visualization Notebook\n",
#      20         "All data is already processed (SBERT embeddings, AI scores, event types, etc.).\n",
#      21         "This notebook only loads the saved results and generates beautiful, publication-ready plots.\n",
#      22         "\n",
# ...
